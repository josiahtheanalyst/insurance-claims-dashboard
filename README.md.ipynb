# %% [markdown]
# # 📊 Finalcial Insurance Claims' & Risk' Interactive Dashboard
#
# ## Overview
# This project presents an **interactive insurance dashboard** built using **Python (Plotly & Pandas)**. It provides a comprehensive overview of customer risk, loan, and claim data, enabling stakeholders to make data-driven decisions efficiently. The dashboard is designed for **financial analysts, insurance managers, and risk assessment teams**. It's an interactive financial insurance dashboard analyzing customer credit risk, claims, and loan approval recommendations.
#
# ## 🔧 Tools Used
# - Python (Pandas, Scikit-learn, Seaborn, Plotly)
# - Google Colab
# - Machine Learning: Random Forest
#
# ## 📈 Key Features
#
# - **KPI Cards**: Quick overview of key metrics:
#   - Average Credit Score
#   - Default Rate (%)
#   - Claim Approval Rate (%)
#   - Loss Ratio (%)
#
# - **Risk Analysis**
#   - Risk distribution by category (interactive donut chart)
#   - Risk segmentation by region (heatmap)
#   - Default rate by risk category
#
# - **Loan & Credit Insights**
#   - Loan-to-income ratio trends by region
#   - Loan amount by employment status
#   - Credit Score vs Default Rate (scatter with trendline)
#
# - **Claims Analysis**
#   - Claims filed per month (interactive line chart)
#   - Claim outcomes and status counts (interactive bar/donut charts)
#
# - **Interactive visualizations (Plotly)**
#
# - **Feature importance via Random Forest**
#
# - **Loan approval recommendations by credit score**
#
# ## Dataset
# The dashboard uses an internal dataset (`df_inner`) containing anonymized customer insurance data with the following columns:
#
# - `customer_id`
# - `income`
# - `loan_amount`
# - `credit_score`
# - `claim_amount`
# - `claim_status`
# - `default_history`
# - `risk_category`
# - `region`
# - `employment_status`
# - `incident_date`
#
# > **Note:** Replace the sample dataset with your own anonymized data as needed.
#
# ---
#
# ## Installation & Usage
#
# 1. **Clone the repository:**
#    ```bash
#    git clone <your-repo-url>
#    cd <repo-folder>

# %% [markdown]
# **2. Install dependencies:**
#
# pip install pandas plotly scikit-learn matplotlib seaborn

# %% [markdown]
# **3. Run the dashboard in Jupyter Notebook or Google Colab:**
#
# %run insurance_dashboard.ipynb

# %% [markdown]
# **4. Interactive Features:**
#
# Hover, zoom, and filter charts directly in the dashboard.

# %% [markdown]
# **4. Requirements File**
#
# pandas
#
# matplotlib
#
# seaborn
#
# scikit-learn
#
# plotly

# %% [markdown]
# ## 🖼️ Sample Dashboard

# %%
from google.colab import drive
drive.mount('/content/drive')   # Mount Google Drive
# !ls "/content/drive/MyDrive"

project_path = "/content/drive/MyDrive/DATA BUSINESS ANALYST MASTER PROJECT/Picture"
import os
os.chdir(project_path)

# confirm files inside
# !ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#  CCCU					'Untitled form (1).gform'
# 'Colab Notebooks'			'Untitled form (File responses)'
# 'DATA BUSINESS ANALYST MASTER PROJECT'	'Untitled form.gform'
# 'RCCG SOLUTION GROUND'
#  eda_dashboard.png  'Visual Schema of the Datasets.png'

# %%
from IPython.display import Image, display

display(Image("/content/drive/MyDrive/DATA BUSINESS ANALYST MASTER PROJECT/Picture/eda_dashboard.png"))

# %% [markdown]
# #**Contribution**
#
# This project is open for enhancements such as:
#
# Adding predictive modeling for customer default probability
#
# Adding filters for dynamic region/period selection
#
# Exporting visuals to PDF/PowerPoint

# %% [markdown]
# # 🚀 **How to Run**
# 1. Clone this repo
# 2. Open the notebook in Jupyter/Colab
# 3. Run all cells

# %% [markdown]
# # 👤** Author**
# Olukayode Josiah
#
# Email: josiahtheanalyst@gmail.com
#
# Olukayode Josiah – [LinkedIn](https://www.linkedin.com/in/YOUR-LINK)
